# %%
# 1. 下载 Anaconda （Python3.8版本） 并安装配置：
# https://www.anaconda.com/products/individual

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
# 国内可以考虑从清华大学开源软件镜像站（Tuna）中去下载：
# https://mirrors.tuna.tsinghua.edu.cn/anaconda/archive/

# %% [markdown]
# ![2.png](attachment:2.png)
